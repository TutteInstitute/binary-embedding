# %% [markdown]
# # (U) Exploratory analysis of the BigBasin dataset
#
# (U) This provides a simple exposition of the structure of the fully-unpacked dataset, along with some tricks and pitfalls for its usage.

# %% [raw]
# import ipydeps
# ipydeps.pip("fsspec ipywidgets matplotlib numpy pandas pyarrow tqdm".split())

# %%
from pathlib import Path
import re

import fsspec
import numpy as np
import pandas as pd
from tqdm.notebook import tqdm_notebook

# %% [markdown]
# (U) Put all relevant secrets for accessing the dataset in an optional `.env` file in the same directory as this notebook. For instance, the data through an Azure Blob Container with a SAS token, one sets up their `.env` file to the following:
#
# ```
# export AZURE_STORAGE_ACCOUNT_NAME="timcarchivestorage"
# export AZURE_STORAGE_SAS_TOKEN="token string, within the quotes"
# ```
#
# (U) For local file system access, no need for a `.env` file.

# %%
# %load_ext dotenv
# %dotenv

# %% [markdown]
# (U) We use [**fsspec**](https://filesystem-spec.readthedocs.io/en/latest/) to abstract away the low-level issues with accessing the dataset. Change the following definition of `PROTOCOL` to the appropriate protocol string for some remote storage technology (e.g. `file` for local file system, `s3` for AWS S3 bucket, `abfs` for Azure Blob Container, etc.)

# %%
PROTOCOL = "abfs"
fs = fsspec.filesystem(PROTOCOL)

# %% [markdown]
# (U) The ROOT variable points to the directory that contains the top level of the unpacked Parquet hierarchy. Note that this value may depend on the access protocol defined above.

# %%
ROOT = "bigbasin/unpacked"

# %% [markdown]
# (U) The following should show a list of cross-compilation architecture tandems if both `PROTOCOL` and `ROOT` were set right.

# %%
fs.ls(ROOT)
# Out:
# ['bigbasin/unpacked/arch=linux-ubuntu18.04-a64fx-AARCH64',
#  'bigbasin/unpacked/arch=linux-ubuntu18.04-aarch64-AARCH64',
#  'bigbasin/unpacked/arch=linux-ubuntu18.04-arm-ARM',
#  'bigbasin/unpacked/arch=linux-ubuntu18.04-arm-x86',
#  'bigbasin/unpacked/arch=linux-ubuntu18.04-broadwell-x86',
#  'bigbasin/unpacked/arch=linux-ubuntu18.04-bulldozer-x86',
#  'bigbasin/unpacked/arch=linux-ubuntu18.04-core2-x86',
#  'bigbasin/unpacked/arch=linux-ubuntu18.04-excavator-x86',
#  'bigbasin/unpacked/arch=linux-ubuntu18.04-graviton-AARCH64',
#  'bigbasin/unpacked/arch=linux-ubuntu18.04-graviton2-AARCH64',
#  'bigbasin/unpacked/arch=linux-ubuntu18.04-haswell-x86',
#  'bigbasin/unpacked/arch=linux-ubuntu18.04-i686-x86',
#  'bigbasin/unpacked/arch=linux-ubuntu18.04-ivybridge-x86',
#  'bigbasin/unpacked/arch=linux-ubuntu18.04-k10-x86',
#  'bigbasin/unpacked/arch=linux-ubuntu18.04-mic_knl-x86',
#  'bigbasin/unpacked/arch=linux-ubuntu18.04-nehalem-x86',
#  'bigbasin/unpacked/arch=linux-ubuntu18.04-nocona-x86',
#  'bigbasin/unpacked/arch=linux-ubuntu18.04-pentium2-x86',
#  'bigbasin/unpacked/arch=linux-ubuntu18.04-pentium3-x86',
#  'bigbasin/unpacked/arch=linux-ubuntu18.04-pentium4-x86',
#  'bigbasin/unpacked/arch=linux-ubuntu18.04-piledriver-x86',
#  'bigbasin/unpacked/arch=linux-ubuntu18.04-power7-PowerPC',
#  'bigbasin/unpacked/arch=linux-ubuntu18.04-power8-PowerPC',
#  'bigbasin/unpacked/arch=linux-ubuntu18.04-power9-PowerPC',
#  'bigbasin/unpacked/arch=linux-ubuntu18.04-ppc-PowerPC',
#  'bigbasin/unpacked/arch=linux-ubuntu18.04-ppc64-PowerPC',
#  'bigbasin/unpacked/arch=linux-ubuntu18.04-ppc64le-PowerPC',
#  'bigbasin/unpacked/arch=linux-ubuntu18.04-prescott-x86',
#  'bigbasin/unpacked/arch=linux-ubuntu18.04-sandybridge-x86',
#  'bigbasin/unpacked/arch=linux-ubuntu18.04-skylake-x86',
#  'bigbasin/unpacked/arch=linux-ubuntu18.04-skylake_avx512-x86',
#  'bigbasin/unpacked/arch=linux-ubuntu18.04-sparc64-Sparc',
#  'bigbasin/unpacked/arch=linux-ubuntu18.04-steamroller-x86',
#  'bigbasin/unpacked/arch=linux-ubuntu18.04-thunderx2-AARCH64',
#  'bigbasin/unpacked/arch=linux-ubuntu18.04-westmere-x86',
#  'bigbasin/unpacked/arch=linux-ubuntu18.04-x86-x86',
#  'bigbasin/unpacked/arch=linux-ubuntu18.04-x86_64-x86',
#  'bigbasin/unpacked/arch=linux-ubuntu18.04-zen-x86',
#  'bigbasin/unpacked/arch=linux-ubuntu21.04-a64fx-AARCH64',
#  'bigbasin/unpacked/arch=linux-ubuntu21.04-aarch64-AARCH64',
#  'bigbasin/unpacked/arch=linux-ubuntu21.04-arm-ARM',
#  'bigbasin/unpacked/arch=linux-ubuntu21.04-broadwell-x86',
#  'bigbasin/unpacked/arch=linux-ubuntu21.04-bulldozer-x86',
#  'bigbasin/unpacked/arch=linux-ubuntu21.04-cannonlake-x86',
#  'bigbasin/unpacked/arch=linux-ubuntu21.04-cascadelake-x86',
#  'bigbasin/unpacked/arch=linux-ubuntu21.04-core2-x86',
#  'bigbasin/unpacked/arch=linux-ubuntu21.04-excavator-x86',
#  'bigbasin/unpacked/arch=linux-ubuntu21.04-graviton-AARCH64',
#  'bigbasin/unpacked/arch=linux-ubuntu21.04-graviton2-AARCH64',
#  'bigbasin/unpacked/arch=linux-ubuntu21.04-haswell-x86',
#  'bigbasin/unpacked/arch=linux-ubuntu21.04-i686-x86',
#  'bigbasin/unpacked/arch=linux-ubuntu21.04-icelake-x86',
#  'bigbasin/unpacked/arch=linux-ubuntu21.04-ivybridge-x86',
#  'bigbasin/unpacked/arch=linux-ubuntu21.04-k10-x86',
#  'bigbasin/unpacked/arch=linux-ubuntu21.04-mic_knl-x86',
#  'bigbasin/unpacked/arch=linux-ubuntu21.04-nehalem-x86',
#  'bigbasin/unpacked/arch=linux-ubuntu21.04-nocona-x86',
#  'bigbasin/unpacked/arch=linux-ubuntu21.04-pentium3-x86',
#  'bigbasin/unpacked/arch=linux-ubuntu21.04-pentium4-x86',
#  'bigbasin/unpacked/arch=linux-ubuntu21.04-piledriver-x86',
#  'bigbasin/unpacked/arch=linux-ubuntu21.04-power7-PowerPC',
#  'bigbasin/unpacked/arch=linux-ubuntu21.04-power8-PowerPC',
#  'bigbasin/unpacked/arch=linux-ubuntu21.04-power9-PowerPC',
#  'bigbasin/unpacked/arch=linux-ubuntu21.04-ppc-PowerPC',
#  'bigbasin/unpacked/arch=linux-ubuntu21.04-ppc64-PowerPC',
#  'bigbasin/unpacked/arch=linux-ubuntu21.04-prescott-x86',
#  'bigbasin/unpacked/arch=linux-ubuntu21.04-sandybridge-x86',
#  'bigbasin/unpacked/arch=linux-ubuntu21.04-skylake-x86',
#  'bigbasin/unpacked/arch=linux-ubuntu21.04-skylake_avx512-x86',
#  'bigbasin/unpacked/arch=linux-ubuntu21.04-sparc64-Sparc',
#  'bigbasin/unpacked/arch=linux-ubuntu21.04-steamroller-x86',
#  'bigbasin/unpacked/arch=linux-ubuntu21.04-thunderx2-AARCH64',
#  'bigbasin/unpacked/arch=linux-ubuntu21.04-westmere-x86',
#  'bigbasin/unpacked/arch=linux-ubuntu21.04-x86-x86',
#  'bigbasin/unpacked/arch=linux-ubuntu21.04-x86_64-x86',
#  'bigbasin/unpacked/arch=linux-ubuntu21.04-zen-x86',
#  'bigbasin/unpacked/arch=linux-ubuntu21.04-zen2-x86']

# %% [markdown]
# ## Partitioning analysis

# %% [markdown]
# How many Parquet files (*leaves*) does this hierarchy hold? We could leverage `pyarrow.dataset.dataset` to hold this information, but as reported below, it's been lacking in robustness for certain purposes involving this dataset.

# %%
# %%time
parquets = [p for p in fs.find(ROOT, withdirs=False) if p.endswith(".parquet")]
len(parquets)
# Out:
# CPU times: user 1min 6s, sys: 902 ms, total: 1min 7s
# Wall time: 1min 38s
# 160931

# %% [markdown]
# That's a lot of partitions! Many systems that build up distributed computations against partitioned data would have trouble processing all of it in one gulp.
#
# Let's take a closer look how the hierarchy is _hived_:

# %%
hive = pd.DataFrame([Path(p).relative_to(ROOT).parts for p in parquets])
with pd.option_context("display.max_colWidth", None):
    display(hive)
# Out:
#                                            0                   1  \
# 0       arch=linux-ubuntu18.04-a64fx-AARCH64  compiler=gcc-7.5.0
# 1       arch=linux-ubuntu18.04-a64fx-AARCH64  compiler=gcc-7.5.0
# 2       arch=linux-ubuntu18.04-a64fx-AARCH64  compiler=gcc-7.5.0
# 3       arch=linux-ubuntu18.04-a64fx-AARCH64  compiler=gcc-7.5.0
# 4       arch=linux-ubuntu18.04-a64fx-AARCH64  compiler=gcc-7.5.0
# ...                                      ...                 ...
# 160926       arch=linux-ubuntu21.04-zen2-x86  compiler=gcc-9.3.0
# 160927       arch=linux-ubuntu21.04-zen2-x86  compiler=gcc-9.3.0
# 160928       arch=linux-ubuntu21.04-zen2-x86  compiler=gcc-9.3.0
# 160929       arch=linux-ubuntu21.04-zen2-x86  compiler=gcc-9.3.0
# 160930       arch=linux-ubuntu21.04-zen2-x86  compiler=gcc-9.3.0
#
#                          2               3  \
# 0       package=aeskeyfind  version=master
# 1         package=earlyoom     version=1.6
# 2           package=figlet   version=2.2.4
# 3           package=figlet   version=2.2.4
# 4            package=flash  version=1.2.11
# ...                    ...             ...
# 160926        package=zlib   version=1.2.8
# 160927        package=zlib   version=1.2.8
# 160928        package=zlib   version=1.2.8
# 160929        package=zlib   version=1.2.8
# 160930        package=zlib   version=1.2.8
#
#                                                                                                                     4
# 0                                 aeskeyfind.4c96ada082b42828d4d9ede6487f370ecbecafec95a5315b8e73c7e8cd30ac26.parquet
# 1                                   earlyoom.849fe438fc62a5981db19d3e0f57338a6ececd407cf19bd42c15768585d1895b.parquet
# 2                                    chkfont.f220efe72fba81c74e7b67edeb7fb3cdbb0d7c94376c38d2967f63a17181d2bf.parquet
# 3                                     figlet.5761c63e7cf0cc0086c91579005198c53bab23020fe27d964e7207e5383670ad.parquet
# 4                                      flash.f2e8ed41b3bd6732c41a81c6400003db5e3071f71a759ebf253122b31cf1a7c6.parquet
# ...                                                                                                               ...
# 160926  libz.so.1.2.8.postprocessed.stripped.3437286233b61ecaf211d7ace3f66b64b08adea4afe53e9d35c47f2dda653f94.parquet
# 160927  libz.so.1.2.8.postprocessed.stripped.387b0930f805c5dc43b62e45b34ca2e1f1acae2ee340da99f5d7a2e8edaff537.parquet
# 160928  libz.so.1.2.8.postprocessed.stripped.52462a04e601dca0343ed6fcb6562374dcd93cc40d09f81315534fd199040e4d.parquet
# 160929  libz.so.1.2.8.postprocessed.stripped.c98d28d693a1327dcfa675017a7579b8649c5dfee543cecc09540d7e4fa3b7d9.parquet
# 160930  libz.so.1.2.8.postprocessed.stripped.d5db3d9352ce3ff23332af63d55f3f0a8f88306a981209c24b7ec3fbff0cd630.parquet
#
# [160931 rows x 5 columns]

# %% [markdown]
# We see 4 explicit partitioning axes:
#
# 1. Cross-compilation architecture tandem: each string is structured as `linux-DISTRO-HOST-TARGET`.
#     1. `DISTRO` is the particular GNU/Linux operating system that is home to both the compiler and the target binary.
#     1. `HOST` is the CPU architecture of the system that builds the binary.
#     1. `TARGET` is the CPU architecture for which the binary is built.
# 1. Compiler and its version.
# 1. Name of the package.
# 1. Nominal package version.
#
# The name of the Parquet file itself seems to contain further information. Plus, seemingly some of the partitioning quadruplets admit more than a single file. This begs the question as to whether more than one binary can belong to any given package. Beyond that, is the data associated to a partitioning quadruplet divided only for file size control, or is there more semantics behind this split?

# %%
hive.columns = ["arch", "compiler", "package", "version", "file"]
hive_agg_count = hive.groupby(["arch", "compiler", "package", "version"]).agg({"file": "count"})
hive_agg_count
# Out:
#                                                                                             file
# arch                                 compiler            package            version
# arch=linux-ubuntu18.04-a64fx-AARCH64 compiler=gcc-7.5.0  package=aeskeyfind version=master     1
#                                                          package=earlyoom   version=1.6        1
#                                                          package=figlet     version=2.2.4      2
#                                                          package=flash      version=1.2.11     1
#                                                          package=iniparser  version=4.1        1
# ...                                                                                          ...
# arch=linux-ubuntu21.04-zen2-x86      compiler=gcc-10.3.0 package=zlib       version=1.2.8     24
#                                      compiler=gcc-11.1.0 package=zlib       version=1.2.11    24
#                                                                             version=1.2.8     24
#                                      compiler=gcc-9.3.0  package=zlib       version=1.2.11    24
#                                                                             version=1.2.8     24
#
# [2655 rows x 1 columns]

# %% [markdown]
# Package `figlet` immediately pops as relevant for asking the first question.

# %%
with pd.option_context("display.max_colWidth", None):
    display(
        hive.loc[
            (hive.arch == "arch=linux-ubuntu18.04-a64fx-AARCH64")
            & (hive.compiler == "compiler=gcc-7.5.0")
            & (hive.package == "package=figlet")
            & (hive.version == "version=2.2.4")
        ]
    )
# Out:
#                                    arch            compiler         package  \
# 2  arch=linux-ubuntu18.04-a64fx-AARCH64  compiler=gcc-7.5.0  package=figlet
# 3  arch=linux-ubuntu18.04-a64fx-AARCH64  compiler=gcc-7.5.0  package=figlet
#
#          version  \
# 2  version=2.2.4
# 3  version=2.2.4
#
#                                                                                file
# 2  chkfont.f220efe72fba81c74e7b67edeb7fb3cdbb0d7c94376c38d2967f63a17181d2bf.parquet
# 3   figlet.5761c63e7cf0cc0086c91579005198c53bab23020fe27d964e7207e5383670ad.parquet

# %% [markdown]
# There effectively seems to be possible for the dataset to store multiple executable for certain packages.
#
# What about packages such as `zlib`, for which there are multiple files, but for which the presence of multiple binaries is not obvious?

# %%
hive_zlib = hive.loc[
    (hive.arch == "arch=linux-ubuntu21.04-zen2-x86")
    & (hive.compiler == "compiler=gcc-11.1.0")
    & (hive.package == "package=zlib")
    & (hive.version == "version=1.2.11")
]
with pd.option_context("display.max_colWidth", None):
    display(hive_zlib)
# Out:
#                                    arch             compiler       package  \
# 160835  arch=linux-ubuntu21.04-zen2-x86  compiler=gcc-11.1.0  package=zlib
# 160836  arch=linux-ubuntu21.04-zen2-x86  compiler=gcc-11.1.0  package=zlib
# 160837  arch=linux-ubuntu21.04-zen2-x86  compiler=gcc-11.1.0  package=zlib
# 160838  arch=linux-ubuntu21.04-zen2-x86  compiler=gcc-11.1.0  package=zlib
# 160839  arch=linux-ubuntu21.04-zen2-x86  compiler=gcc-11.1.0  package=zlib
# 160840  arch=linux-ubuntu21.04-zen2-x86  compiler=gcc-11.1.0  package=zlib
# 160841  arch=linux-ubuntu21.04-zen2-x86  compiler=gcc-11.1.0  package=zlib
# 160842  arch=linux-ubuntu21.04-zen2-x86  compiler=gcc-11.1.0  package=zlib
# 160843  arch=linux-ubuntu21.04-zen2-x86  compiler=gcc-11.1.0  package=zlib
# 160844  arch=linux-ubuntu21.04-zen2-x86  compiler=gcc-11.1.0  package=zlib
# 160845  arch=linux-ubuntu21.04-zen2-x86  compiler=gcc-11.1.0  package=zlib
# 160846  arch=linux-ubuntu21.04-zen2-x86  compiler=gcc-11.1.0  package=zlib
# 160847  arch=linux-ubuntu21.04-zen2-x86  compiler=gcc-11.1.0  package=zlib
# 160848  arch=linux-ubuntu21.04-zen2-x86  compiler=gcc-11.1.0  package=zlib
# 160849  arch=linux-ubuntu21.04-zen2-x86  compiler=gcc-11.1.0  package=zlib
# 160850  arch=linux-ubuntu21.04-zen2-x86  compiler=gcc-11.1.0  package=zlib
# 160851  arch=linux-ubuntu21.04-zen2-x86  compiler=gcc-11.1.0  package=zlib
# 160852  arch=linux-ubuntu21.04-zen2-x86  compiler=gcc-11.1.0  package=zlib
# 160853  arch=linux-ubuntu21.04-zen2-x86  compiler=gcc-11.1.0  package=zlib
# 160854  arch=linux-ubuntu21.04-zen2-x86  compiler=gcc-11.1.0  package=zlib
# 160855  arch=linux-ubuntu21.04-zen2-x86  compiler=gcc-11.1.0  package=zlib
# 160856  arch=linux-ubuntu21.04-zen2-x86  compiler=gcc-11.1.0  package=zlib
# 160857  arch=linux-ubuntu21.04-zen2-x86  compiler=gcc-11.1.0  package=zlib
# 160858  arch=linux-ubuntu21.04-zen2-x86  compiler=gcc-11.1.0  package=zlib
#
#                version  \
# 160835  version=1.2.11
# 160836  version=1.2.11
# 160837  version=1.2.11
# 160838  version=1.2.11
# 160839  version=1.2.11
# 160840  version=1.2.11
# 160841  version=1.2.11
# 160842  version=1.2.11
# 160843  version=1.2.11
# 160844  version=1.2.11
# 160845  version=1.2.11
# 160846  version=1.2.11
# 160847  version=1.2.11
# 160848  version=1.2.11
# 160849  version=1.2.11
# 160850  version=1.2.11
# 160851  version=1.2.11
# 160852  version=1.2.11
# 160853  version=1.2.11
# 160854  version=1.2.11
# 160855  version=1.2.11
# 160856  version=1.2.11
# 160857  version=1.2.11
# 160858  version=1.2.11
#
#                                                                                                                           file
# 160835                                 libz.so.1.2.11.11bff7576adb32be81a9dffde950ec1b3c1635a5a2adf640c33d37e17486f7dd.parquet
# 160836                                 libz.so.1.2.11.168ffad0ead04b0615a23592c9687b9ad9035984472dfd004b369046e21a9ab6.parquet
# 160837                                 libz.so.1.2.11.897b4396bbfdcfd5a11dec926077c56cb1fc1fcbddaba7ad9a2ae5fcec55b3e6.parquet
# 160838                                 libz.so.1.2.11.cb0ae46af0ece152373862882cbb9ffb97e6d8454e6a7ce6c6990815c63dcad6.parquet
# 160839                                 libz.so.1.2.11.e0a042ac5d8cf84880821d67e2e83fbff4b2f42ff4196409edd80522a1c1bfb2.parquet
# 160840                                 libz.so.1.2.11.ede647019b947ffa6c6593ccdc575d372f56153800cefbbab2276370eccb9bee.parquet
# 160841    libz.so.1.2.11.postprocessed.kiteshield-all.1f156c90ee84453ea75badb3b8bb70c9f540dfe94601dc8f7584d905bd10d7e9.parquet
# 160842    libz.so.1.2.11.postprocessed.kiteshield-all.2d0d0645a79ecad5c5961daaa9c275f366ce9279ade08f742bf0ffe675c4e59f.parquet
# 160843    libz.so.1.2.11.postprocessed.kiteshield-all.4a1a099c3a465a914ec1a50635782bf7469c1d6a40a3b94d0997ace0385a6dae.parquet
# 160844    libz.so.1.2.11.postprocessed.kiteshield-all.a0d933a016a46cdbbf636bd5d82c3c4ed458929e51be6ff0980bfffca6396d2b.parquet
# 160845    libz.so.1.2.11.postprocessed.kiteshield-all.a9f901c0bba9edacd00faa861afae81261c6655614fa4ff63a0c9e88d5da90fa.parquet
# 160846    libz.so.1.2.11.postprocessed.kiteshield-all.ed7aeb89a31382fd85c5ccb5f632dd5050f917cc4804874e65c3c9942968420d.parquet
# 160847  libz.so.1.2.11.postprocessed.kiteshield-outer.0a8de07d262febb407c34f4bba7a6b30bd4d218f6690ea642d40e20e53ee1556.parquet
# 160848  libz.so.1.2.11.postprocessed.kiteshield-outer.11946a2f5179c57bbcde800f43b23ed23a163fe10c265771c6f82dedb45c5db0.parquet
# 160849  libz.so.1.2.11.postprocessed.kiteshield-outer.26ceac6413f71927ce6d17cf456864952a9e34e990a208fb14966f63aabeba4b.parquet
# 160850  libz.so.1.2.11.postprocessed.kiteshield-outer.c6aefe4599f0282b4446fa89903349357d54531b64733883d246ed8ef6915184.parquet
# 160851  libz.so.1.2.11.postprocessed.kiteshield-outer.de9d6c76612e3327f75aa5e36b6f4dc11d412b2f107a4a155d5bd7e696bb4394.parquet
# 160852  libz.so.1.2.11.postprocessed.kiteshield-outer.f87a73117da2812ebf9dbf652c1fb193c0041d5021e570daf0948f204d6fdd3c.parquet
# 160853          libz.so.1.2.11.postprocessed.stripped.07a5e2ed28be9e0ecbbbfe737eb87c69a8712ee27d06b0432eec83dfed95df61.parquet
# 160854          libz.so.1.2.11.postprocessed.stripped.251f784c06511fddea231b65b6e027613deae5c8ce07b479f58f0d3f25641620.parquet
# 160855          libz.so.1.2.11.postprocessed.stripped.2c0d2184ebfa73320552c195be0d7a31740fd23d857a937e0ac969e3e3bcf00a.parquet
# 160856          libz.so.1.2.11.postprocessed.stripped.5097a308a4b9159aeb84780b69eb0851c7521e52ea2111942ad6fbeec0598d0f.parquet
# 160857          libz.so.1.2.11.postprocessed.stripped.9d82982f6ed4fb578d2f8f3741331d74d8b87588c76fdbd4f1f341fa01156233.parquet
# 160858          libz.so.1.2.11.postprocessed.stripped.a390c7f37220a698d41a9d0291644109158017e3fa763b4cec0fbdcb0584c255.parquet

# %% [markdown]
# The names in play suggest that each file could correspond to a distinct compiler configuration. Let's dig into each file to check this hypothesis.

# %%
data_zlib = pd.concat(
    [
        pd.read_parquet(f"{PROTOCOL}://{parquets[i]}").assign(path=parquets[i])
        for i in hive_zlib.index
    ],
    ignore_index=True
)
data_zlib
# Out:
#                           r_arch  r_compiler r_package r_version  \
# 0     linux-ubuntu21.04-zen2-x86  gcc-11.1.0      zlib    1.2.11
# 1     linux-ubuntu21.04-zen2-x86  gcc-11.1.0      zlib    1.2.11
# 2     linux-ubuntu21.04-zen2-x86  gcc-11.1.0      zlib    1.2.11
# 3     linux-ubuntu21.04-zen2-x86  gcc-11.1.0      zlib    1.2.11
# 4     linux-ubuntu21.04-zen2-x86  gcc-11.1.0      zlib    1.2.11
# ...                          ...         ...       ...       ...
# 2023  linux-ubuntu21.04-zen2-x86  gcc-11.1.0      zlib    1.2.11
# 2024  linux-ubuntu21.04-zen2-x86  gcc-11.1.0      zlib    1.2.11
# 2025  linux-ubuntu21.04-zen2-x86  gcc-11.1.0      zlib    1.2.11
# 2026  linux-ubuntu21.04-zen2-x86  gcc-11.1.0      zlib    1.2.11
# 2027  linux-ubuntu21.04-zen2-x86  gcc-11.1.0      zlib    1.2.11
#
#      compile_options compile_options_hash  \
# 0                -O2         tfsvZKJmhgbt
# 1                -O2         tfsvZKJmhgbt
# 2                -O2         tfsvZKJmhgbt
# 3                -O2         tfsvZKJmhgbt
# 4                -O2         tfsvZKJmhgbt
# ...              ...                  ...
# 2023             -Os         hY6x3CeUOd5O
# 2024             -Os         hY6x3CeUOd5O
# 2025             -Os         hY6x3CeUOd5O
# 2026             -Os         hY6x3CeUOd5O
# 2027             -Os         hY6x3CeUOd5O
#
#                                    bin_name  bin_size  \
# 0                            libz.so.1.2.11    109200
# 1                            libz.so.1.2.11    109200
# 2                            libz.so.1.2.11    109200
# 3                            libz.so.1.2.11    109200
# 4                            libz.so.1.2.11    109200
# ...                                     ...       ...
# 2023  libz.so.1.2.11.postprocessed.stripped    100936
# 2024  libz.so.1.2.11.postprocessed.stripped    100936
# 2025  libz.so.1.2.11.postprocessed.stripped    100936
# 2026  libz.so.1.2.11.postprocessed.stripped    100936
# 2027  libz.so.1.2.11.postprocessed.stripped    100936
#
#                                bin_md5  \
# 0     ce6ec7c4196041386413eb36472889fd
# 1     ce6ec7c4196041386413eb36472889fd
# 2     ce6ec7c4196041386413eb36472889fd
# 3     ce6ec7c4196041386413eb36472889fd
# 4     ce6ec7c4196041386413eb36472889fd
# ...                                ...
# 2023  ee9ec2729dcdfb409f48eac7f3c9277c
# 2024  ee9ec2729dcdfb409f48eac7f3c9277c
# 2025  ee9ec2729dcdfb409f48eac7f3c9277c
# 2026  ee9ec2729dcdfb409f48eac7f3c9277c
# 2027  ee9ec2729dcdfb409f48eac7f3c9277c
#
#                                              bin_sha256  \
# 0     a93cc0233af92bbd6863074c2283260efaca634e01b8bb...
# 1     a93cc0233af92bbd6863074c2283260efaca634e01b8bb...
# 2     a93cc0233af92bbd6863074c2283260efaca634e01b8bb...
# 3     a93cc0233af92bbd6863074c2283260efaca634e01b8bb...
# 4     a93cc0233af92bbd6863074c2283260efaca634e01b8bb...
# ...                                                 ...
# 2023  fee270a141917e9be1d8dabacf72868b5b8327ff4fb194...
# 2024  fee270a141917e9be1d8dabacf72868b5b8327ff4fb194...
# 2025  fee270a141917e9be1d8dabacf72868b5b8327ff4fb194...
# 2026  fee270a141917e9be1d8dabacf72868b5b8327ff4fb194...
# 2027  fee270a141917e9be1d8dabacf72868b5b8327ff4fb194...
#
#                   func_name func_addr_start func_addr_end  \
# 0                     _init        00103000      0010301a
# 1              FUN_00103020        00103020      0010302c
# 2      deregister_tm_clones        001035e0      00103608
# 3        register_tm_clones        00103610      00103648
# 4     __do_global_dtors_aux        00103650      00103688
# ...                     ...             ...           ...
# 2023               gzprintf        001106a0      0011075c
# 2024                gzflush        00110760      001107dc
# 2025            gzsetparams        001107e0      001108b7
# 2026              gzclose_w        001108c0      001109b7
# 2027               _DT_FINI        001109b8      001109c4
#
#                                            basic_blocks  \
# 0     [{'blk_addr_start': '00103000', 'blk_id': 0, '...
# 1     [{'blk_addr_start': '00103020', 'blk_id': 0, '...
# 2     [{'blk_addr_start': '001035e0', 'blk_id': 0, '...
# 3     [{'blk_addr_start': '00103610', 'blk_id': 0, '...
# 4     [{'blk_addr_start': '00103650', 'blk_id': 0, '...
# ...                                                 ...
# 2023  [{'blk_addr_start': '001106a0', 'blk_id': 0, '...
# 2024  [{'blk_addr_start': '00110760', 'blk_id': 0, '...
# 2025  [{'blk_addr_start': '001107e0', 'blk_id': 0, '...
# 2026  [{'blk_addr_start': '001108c0', 'blk_id': 0, '...
# 2027  [{'blk_addr_start': '001109b8', 'blk_id': 0, '...
#
#                                        func_asm_summary  \
# 0     [{'asm_scrub_type': 'mode_2', 'func_asm_hash':...
# 1     [{'asm_scrub_type': 'mode_2', 'func_asm_hash':...
# 2     [{'asm_scrub_type': 'mode_2', 'func_asm_hash':...
# 3     [{'asm_scrub_type': 'mode_2', 'func_asm_hash':...
# 4     [{'asm_scrub_type': 'mode_2', 'func_asm_hash':...
# ...                                                 ...
# 2023  [{'asm_scrub_type': 'no_scrub', 'func_asm_hash...
# 2024  [{'asm_scrub_type': 'no_scrub', 'func_asm_hash...
# 2025  [{'asm_scrub_type': 'no_scrub', 'func_asm_hash...
# 2026  [{'asm_scrub_type': 'no_scrub', 'func_asm_hash...
# 2027  [{'asm_scrub_type': 'no_scrub', 'func_asm_hash...
#
#                                                   pcode  \
# 0     [{'hi_pcode': ['r8I4zCth3MxqDkqw', 'i3dHXOZLeS...
# 1     [{'hi_pcode': ['g6uDeuvdQTWjaBP4', 'p1_ah6QRdO...
# 2     [{'hi_pcode': ['XlH8FVpskIWnFx7-'], 'hi_pcode_...
# 3     [{'hi_pcode': ['XlH8FVpskIWnFx7-'], 'hi_pcode_...
# 4     [{'hi_pcode': ['sO4_DgLqQuPE2OEN', 'ikCekTeW5J...
# ...                                                 ...
# 2023  [{'hi_pcode': ['0tLbt_4c_5SP2YRK', 'fw115HVidD...
# 2024  [{'hi_pcode': ['GRmP1MsYMKIL9_bn', 'gV_5rftzsd...
# 2025  [{'hi_pcode': ['GRmP1MsYMKIL9_bn', 'GQi3lFs73L...
# 2026  [{'hi_pcode': ['GRmP1MsYMKIL9_bn', 'Ghj9aPBJAG...
# 2027  [{'hi_pcode': ['XlH8FVpskIWnFx7-'], 'hi_pcode_...
#
#                                                    path
# 0     bigbasin/unpacked/arch=linux-ubuntu21.04-zen2-...
# 1     bigbasin/unpacked/arch=linux-ubuntu21.04-zen2-...
# 2     bigbasin/unpacked/arch=linux-ubuntu21.04-zen2-...
# 3     bigbasin/unpacked/arch=linux-ubuntu21.04-zen2-...
# 4     bigbasin/unpacked/arch=linux-ubuntu21.04-zen2-...
# ...                                                 ...
# 2023  bigbasin/unpacked/arch=linux-ubuntu21.04-zen2-...
# 2024  bigbasin/unpacked/arch=linux-ubuntu21.04-zen2-...
# 2025  bigbasin/unpacked/arch=linux-ubuntu21.04-zen2-...
# 2026  bigbasin/unpacked/arch=linux-ubuntu21.04-zen2-...
# 2027  bigbasin/unpacked/arch=linux-ubuntu21.04-zen2-...
#
# [2028 rows x 17 columns]

# %%
data_zlib_agg_compile_options = data_zlib.groupby("path").agg({"compile_options": "nunique"})
data_zlib_agg_compile_options
# Out:
#                                                     compile_options
# path
# bigbasin/unpacked/arch=linux-ubuntu21.04-zen2-x...                1
# bigbasin/unpacked/arch=linux-ubuntu21.04-zen2-x...                1
# bigbasin/unpacked/arch=linux-ubuntu21.04-zen2-x...                1
# bigbasin/unpacked/arch=linux-ubuntu21.04-zen2-x...                1
# bigbasin/unpacked/arch=linux-ubuntu21.04-zen2-x...                1
# bigbasin/unpacked/arch=linux-ubuntu21.04-zen2-x...                1
# bigbasin/unpacked/arch=linux-ubuntu21.04-zen2-x...                1
# bigbasin/unpacked/arch=linux-ubuntu21.04-zen2-x...                1
# bigbasin/unpacked/arch=linux-ubuntu21.04-zen2-x...                1
# bigbasin/unpacked/arch=linux-ubuntu21.04-zen2-x...                1
# bigbasin/unpacked/arch=linux-ubuntu21.04-zen2-x...                1
# bigbasin/unpacked/arch=linux-ubuntu21.04-zen2-x...                1
# bigbasin/unpacked/arch=linux-ubuntu21.04-zen2-x...                1
# bigbasin/unpacked/arch=linux-ubuntu21.04-zen2-x...                1
# bigbasin/unpacked/arch=linux-ubuntu21.04-zen2-x...                1
# bigbasin/unpacked/arch=linux-ubuntu21.04-zen2-x...                1
# bigbasin/unpacked/arch=linux-ubuntu21.04-zen2-x...                1
# bigbasin/unpacked/arch=linux-ubuntu21.04-zen2-x...                1
# bigbasin/unpacked/arch=linux-ubuntu21.04-zen2-x...                1
# bigbasin/unpacked/arch=linux-ubuntu21.04-zen2-x...                1
# bigbasin/unpacked/arch=linux-ubuntu21.04-zen2-x...                1
# bigbasin/unpacked/arch=linux-ubuntu21.04-zen2-x...                1
# bigbasin/unpacked/arch=linux-ubuntu21.04-zen2-x...                1
# bigbasin/unpacked/arch=linux-ubuntu21.04-zen2-x...                1

# %% [markdown]
# This confirms that all records within each Parquet file share a single compilation configuration, as described in column `compile_options`.
#
# There still seems to be more of such information embedded in the name of the binary (`bin_name`). Indeed, sometimes such names have a `.postprocessed` component. Let's unpack this.

# %%
data_zlib["postprocessing"] = data_zlib["bin_name"].str.split(".postprocessed.").apply(lambda x: x[-1] if x[-1] != x[0] else "vanilla")
data_zlib_agg_co_pp = data_zlib.groupby(["compile_options", "postprocessing"]).agg({"path": "nunique"})
data_zlib_agg_co_pp.unstack("postprocessing")
# Out:
#                           path
# postprocessing  kiteshield-all kiteshield-outer stripped vanilla
# compile_options
# -O0                          1                1        1       1
# -O1                          1                1        1       1
# -O2                          1                1        1       1
# -O3                          1                1        1       1
# -Og                          1                1        1       1
# -Os                          1                1        1       1

# %% [markdown]
# This confirms this package effectively sports a distinct Parquet file for each compilation configuration.

# %% [markdown]
# ## Deciding on a data subset for experimenting

# %% [markdown]
# The goal of research on this dataset is to compare binaries. Assumptions:
#
# 1. Binaries coming from distinct source codes should be distinct (dissimilar).
#     1. Binaries that share functions at the source level or statically-compiled libraries should be more similar.
# 1. Binaries coming from the same source code should be similar across compilers.
# 1. Binaries coming from the same source code should be more or less similar depending on compiler configurations.
#     1. A higher degree of optimization should decrease similarity.
# 1. Binaries compiled from distinct host architecture should be similar.
# 1. Across successive versions, binaries should tend to be similar.
#
# Most experiments would verify assumption 1 -- it's a basic sanity check, really. Let's focus on evaluating assumption 5 as well, selecting one architecture tandem and compiler that enables it best.

# %%
tandems_x_compilers = (
    hive
    .groupby(["arch", "compiler"])
    .agg({"package": "nunique"})
    .unstack("compiler")
)
tandems_x_compilers.replace(np.nan, "")
# Out:
#                                                    package  \
# compiler                               compiler=aocc-3_1_0
# arch
# arch=linux-ubuntu18.04-a64fx-AARCH64
# arch=linux-ubuntu18.04-aarch64-AARCH64
# arch=linux-ubuntu18.04-arm-ARM
# arch=linux-ubuntu18.04-arm-x86
# arch=linux-ubuntu18.04-broadwell-x86
# ...                                                    ...
# arch=linux-ubuntu21.04-westmere-x86
# arch=linux-ubuntu21.04-x86-x86
# arch=linux-ubuntu21.04-x86_64-x86
# arch=linux-ubuntu21.04-zen-x86
# arch=linux-ubuntu21.04-zen2-x86
#
#                                                               \
# compiler                               compiler=clang-11.0.1
# arch
# arch=linux-ubuntu18.04-a64fx-AARCH64
# arch=linux-ubuntu18.04-aarch64-AARCH64
# arch=linux-ubuntu18.04-arm-ARM
# arch=linux-ubuntu18.04-arm-x86
# arch=linux-ubuntu18.04-broadwell-x86
# ...                                                      ...
# arch=linux-ubuntu21.04-westmere-x86
# arch=linux-ubuntu21.04-x86-x86
# arch=linux-ubuntu21.04-x86_64-x86                       92.0
# arch=linux-ubuntu21.04-zen-x86
# arch=linux-ubuntu21.04-zen2-x86
#
#                                                               \
# compiler                               compiler=clang-12.0.0
# arch
# arch=linux-ubuntu18.04-a64fx-AARCH64
# arch=linux-ubuntu18.04-aarch64-AARCH64
# arch=linux-ubuntu18.04-arm-ARM
# arch=linux-ubuntu18.04-arm-x86
# arch=linux-ubuntu18.04-broadwell-x86
# ...                                                      ...
# arch=linux-ubuntu21.04-westmere-x86
# arch=linux-ubuntu21.04-x86-x86
# arch=linux-ubuntu21.04-x86_64-x86                       85.0
# arch=linux-ubuntu21.04-zen-x86
# arch=linux-ubuntu21.04-zen2-x86
#
#                                                              \
# compiler                               compiler=clang-6.0.0
# arch
# arch=linux-ubuntu18.04-a64fx-AARCH64
# arch=linux-ubuntu18.04-aarch64-AARCH64
# arch=linux-ubuntu18.04-arm-ARM
# arch=linux-ubuntu18.04-arm-x86
# arch=linux-ubuntu18.04-broadwell-x86
# ...                                                     ...
# arch=linux-ubuntu21.04-westmere-x86
# arch=linux-ubuntu21.04-x86-x86
# arch=linux-ubuntu21.04-x86_64-x86
# arch=linux-ubuntu21.04-zen-x86
# arch=linux-ubuntu21.04-zen2-x86
#
#                                                              \
# compiler                               compiler=clang-9.0.1
# arch
# arch=linux-ubuntu18.04-a64fx-AARCH64
# arch=linux-ubuntu18.04-aarch64-AARCH64
# arch=linux-ubuntu18.04-arm-ARM
# arch=linux-ubuntu18.04-arm-x86
# arch=linux-ubuntu18.04-broadwell-x86
# ...                                                     ...
# arch=linux-ubuntu21.04-westmere-x86
# arch=linux-ubuntu21.04-x86-x86
# arch=linux-ubuntu21.04-x86_64-x86                      96.0
# arch=linux-ubuntu21.04-zen-x86
# arch=linux-ubuntu21.04-zen2-x86
#
#                                                             \
# compiler                               compiler=gcc-10.3.0
# arch
# arch=linux-ubuntu18.04-a64fx-AARCH64
# arch=linux-ubuntu18.04-aarch64-AARCH64
# arch=linux-ubuntu18.04-arm-ARM
# arch=linux-ubuntu18.04-arm-x86
# arch=linux-ubuntu18.04-broadwell-x86
# ...                                                    ...
# arch=linux-ubuntu21.04-westmere-x86                    8.0
# arch=linux-ubuntu21.04-x86-x86                         1.0
# arch=linux-ubuntu21.04-x86_64-x86                    113.0
# arch=linux-ubuntu21.04-zen-x86                         1.0
# arch=linux-ubuntu21.04-zen2-x86                        1.0
#
#                                                                                \
# compiler                               compiler=gcc-11.1.0 compiler=gcc-7.5.0
# arch
# arch=linux-ubuntu18.04-a64fx-AARCH64                                      8.0
# arch=linux-ubuntu18.04-aarch64-AARCH64                                    1.0
# arch=linux-ubuntu18.04-arm-ARM                                            3.0
# arch=linux-ubuntu18.04-arm-x86                                            1.0
# arch=linux-ubuntu18.04-broadwell-x86                                      1.0
# ...                                                    ...                ...
# arch=linux-ubuntu21.04-westmere-x86                    8.0
# arch=linux-ubuntu21.04-x86-x86                         1.0
# arch=linux-ubuntu21.04-x86_64-x86                    128.0
# arch=linux-ubuntu21.04-zen-x86                         1.0
# arch=linux-ubuntu21.04-zen2-x86                        1.0
#
#                                                            \
# compiler                               compiler=gcc-9.3.0
# arch
# arch=linux-ubuntu18.04-a64fx-AARCH64
# arch=linux-ubuntu18.04-aarch64-AARCH64
# arch=linux-ubuntu18.04-arm-ARM
# arch=linux-ubuntu18.04-arm-x86
# arch=linux-ubuntu18.04-broadwell-x86
# ...                                                   ...
# arch=linux-ubuntu21.04-westmere-x86                   1.0
# arch=linux-ubuntu21.04-x86-x86                        1.0
# arch=linux-ubuntu21.04-x86_64-x86                   110.0
# arch=linux-ubuntu21.04-zen-x86                        1.0
# arch=linux-ubuntu21.04-zen2-x86                       1.0
#
#                                                                 \
# compiler                               compiler=intel-2021.2.0
# arch
# arch=linux-ubuntu18.04-a64fx-AARCH64
# arch=linux-ubuntu18.04-aarch64-AARCH64
# arch=linux-ubuntu18.04-arm-ARM
# arch=linux-ubuntu18.04-arm-x86
# arch=linux-ubuntu18.04-broadwell-x86
# ...                                                        ...
# arch=linux-ubuntu21.04-westmere-x86
# arch=linux-ubuntu21.04-x86-x86
# arch=linux-ubuntu21.04-x86_64-x86
# arch=linux-ubuntu21.04-zen-x86
# arch=linux-ubuntu21.04-zen2-x86
#
#
# compiler                               compiler=nvhpc-21.3
# arch
# arch=linux-ubuntu18.04-a64fx-AARCH64
# arch=linux-ubuntu18.04-aarch64-AARCH64
# arch=linux-ubuntu18.04-arm-ARM
# arch=linux-ubuntu18.04-arm-x86
# arch=linux-ubuntu18.04-broadwell-x86
# ...                                                    ...
# arch=linux-ubuntu21.04-westmere-x86
# arch=linux-ubuntu21.04-x86-x86
# arch=linux-ubuntu21.04-x86_64-x86
# arch=linux-ubuntu21.04-zen-x86
# arch=linux-ubuntu21.04-zen2-x86
#
# [77 rows x 11 columns]

# %%
tandems_x_compilers.stack()
# Out:
#                                                             package
# arch                                   compiler
# arch=linux-ubuntu18.04-a64fx-AARCH64   compiler=gcc-7.5.0       8.0
# arch=linux-ubuntu18.04-aarch64-AARCH64 compiler=gcc-7.5.0       1.0
# arch=linux-ubuntu18.04-arm-ARM         compiler=gcc-7.5.0       3.0
# arch=linux-ubuntu18.04-arm-x86         compiler=gcc-7.5.0       1.0
# arch=linux-ubuntu18.04-broadwell-x86   compiler=gcc-7.5.0       1.0
# ...                                                             ...
# arch=linux-ubuntu21.04-zen-x86         compiler=gcc-11.1.0      1.0
#                                        compiler=gcc-9.3.0       1.0
# arch=linux-ubuntu21.04-zen2-x86        compiler=gcc-10.3.0      1.0
#                                        compiler=gcc-11.1.0      1.0
#                                        compiler=gcc-9.3.0       1.0
#
# [174 rows x 1 columns]

# %% [markdown]
# Let's filter this down a bit: any tandem and compiler combo with less than 100 packages to explore is obviously no-go.

# %%
txc_stacked = tandems_x_compilers.stack()
txc100 = txc_stacked.loc[txc_stacked["package"] >= 100.0].unstack("compiler")
txc100.replace(np.nan, "")
# Out:
#                                                package                      \
# compiler                          compiler=clang-6.0.0 compiler=gcc-10.3.0
# arch
# arch=linux-ubuntu18.04-x86_64-x86                112.0               101.0
# arch=linux-ubuntu21.04-x86_64-x86                                    113.0
#
#                                                                          \
# compiler                          compiler=gcc-7.5.0 compiler=gcc-9.3.0
# arch
# arch=linux-ubuntu18.04-x86_64-x86              121.0              105.0
# arch=linux-ubuntu21.04-x86_64-x86                                 110.0
#
#
# compiler                          compiler=intel-2021.2.0 compiler=gcc-11.1.0
# arch
# arch=linux-ubuntu18.04-x86_64-x86                   110.0
# arch=linux-ubuntu21.04-x86_64-x86                                       128.0

# %% [markdown]
# The choice is now much easier. We will use the architecture tandem `linux-ubuntu21.04-x86_64-x86` and compiler `gcc-11.1.0`. Let's measure the number of versions for each package.

# %%
hive_selected = hive.loc[
    (hive["arch"] == "arch=linux-ubuntu21.04-x86_64-x86")
    & (hive["compiler"] == "compiler=gcc-11.1.0")
].drop(columns=["arch", "compiler"])
hive_selected
# Out:
#                       package        version  \
# 112572  package=activeharmony  version=4.6.0
# 112573  package=activeharmony  version=4.6.0
# 112574  package=activeharmony  version=4.6.0
# 112575  package=activeharmony  version=4.6.0
# 112576  package=activeharmony  version=4.6.0
# ...                       ...            ...
# 152044           package=zstd  version=1.4.5
# 152045           package=zstd  version=1.4.5
# 152046           package=zstd  version=1.4.5
# 152047           package=zstd  version=1.4.5
# 152048           package=zstd  version=1.4.5
#
#                                                      file
# 112572  agg.so.36a81602bddf2f541896823e823f0ef1f926e9e...
# 112573  agg.so.57923f7e852de6542122911d54c7acce3f2dccc...
# 112574  agg.so.5d5dcab6f344bf089fa0e70d771c863e60b279c...
# 112575  agg.so.7692f55d8154308fd3c85c97120c58446927e5a...
# 112576  agg.so.af2129723349b12ae72d53d65ce6fe2362562cf...
# ...                                                   ...
# 152044  zstd.postprocessed.kiteshield-outer.b6cedac767...
# 152045  zstd.postprocessed.upx-1.bd17cf0506318084f3108...
# 152046  zstd.postprocessed.upx-1.cb0a2efb14054e20fb465...
# 152047  zstd.postprocessed.upx-best.145f04c3b68e1e3d8e...
# 152048  zstd.postprocessed.upx-best.ad219010f63c0ee973...
#
# [39477 rows x 3 columns]

# %%
hive_selected_package_versions = (
    hive_selected
    .groupby("package")
    .agg({"version": "nunique"})
)
hive_selected_package_versions
# Out:
#                        version
# package
# package=activeharmony        1
# package=aeskeyfind           1
# package=agrep                1
# package=alglib               1
# package=aragorn              2
# ...                        ...
# package=wtdbg2               1
# package=xxhash               4
# package=xz                   1
# package=zlib                 2
# package=zstd                 8
#
# [128 rows x 1 columns]

# %% [markdown]
# Many of these have only one version. Let's focus on those with at least 2.

# %%
df_packages_selected = hive_selected_package_versions.loc[
    hive_selected_package_versions["version"] > 1
]
df_packages_selected
# Out:
#                      version
# package
# package=aragorn            2
# package=argon2             3
# package=blktrace           2
# package=cachefilesd        5
# package=earlyoom           2
# package=figlet             3
# package=haproxy            2
# package=hardlink           2
# package=hiredis            4
# package=iniparser          4
# package=jimtcl             3
# package=keyutils           4
# package=libjson            5
# package=libsvm             2
# package=libtomlc99         2
# package=lizard             2
# package=lmdb               3
# package=lshw               4
# package=lsof               3
# package=nyancat            4
# package=openssl            5
# package=pigz               2
# package=predixy            3
# package=primer3            2
# package=rsbench            2
# package=samblaster         2
# package=seqtk              3
# package=star              12
# package=sysget             3
# package=tetgen             2
# package=tree               2
# package=vt                 2
# package=xxhash             4
# package=zlib               2
# package=zstd               8

# %%
packages_selected = set(df_packages_selected.index)
len(packages_selected)
# Out:
# 35

# %% [markdown]
# This looks like a suitable subset: small enough for experimentation to be fast, large enough for results to matter. How many binaries are thus in play?

# %%
hive_selected
# Out:
#                       package        version  \
# 112572  package=activeharmony  version=4.6.0
# 112573  package=activeharmony  version=4.6.0
# 112574  package=activeharmony  version=4.6.0
# 112575  package=activeharmony  version=4.6.0
# 112576  package=activeharmony  version=4.6.0
# ...                       ...            ...
# 152044           package=zstd  version=1.4.5
# 152045           package=zstd  version=1.4.5
# 152046           package=zstd  version=1.4.5
# 152047           package=zstd  version=1.4.5
# 152048           package=zstd  version=1.4.5
#
#                                                      file
# 112572  agg.so.36a81602bddf2f541896823e823f0ef1f926e9e...
# 112573  agg.so.57923f7e852de6542122911d54c7acce3f2dccc...
# 112574  agg.so.5d5dcab6f344bf089fa0e70d771c863e60b279c...
# 112575  agg.so.7692f55d8154308fd3c85c97120c58446927e5a...
# 112576  agg.so.af2129723349b12ae72d53d65ce6fe2362562cf...
# ...                                                   ...
# 152044  zstd.postprocessed.kiteshield-outer.b6cedac767...
# 152045  zstd.postprocessed.upx-1.bd17cf0506318084f3108...
# 152046  zstd.postprocessed.upx-1.cb0a2efb14054e20fb465...
# 152047  zstd.postprocessed.upx-best.145f04c3b68e1e3d8e...
# 152048  zstd.postprocessed.upx-best.ad219010f63c0ee973...
#
# [39477 rows x 3 columns]

# %%
subset_exp = hive_selected.loc[hive_selected["package"].isin(packages_selected)]
subset_exp
# Out:
#                 package         version  \
# 112734  package=aragorn  version=1.2.36
# 112735  package=aragorn  version=1.2.36
# 112736  package=aragorn  version=1.2.36
# 112737  package=aragorn  version=1.2.36
# 112738  package=aragorn  version=1.2.36
# ...                 ...             ...
# 152044     package=zstd   version=1.4.5
# 152045     package=zstd   version=1.4.5
# 152046     package=zstd   version=1.4.5
# 152047     package=zstd   version=1.4.5
# 152048     package=zstd   version=1.4.5
#
#                                                      file
# 112734  aragorn.04e26c90c5323cc4f4677bbeed81396beba82e...
# 112735  aragorn.4ba4380fdf8f54e45ad7c138cafb9d61ede70d...
# 112736  aragorn.4fa7ba312c88261d9a2795b0d65d095c1b0548...
# 112737  aragorn.58f16bf402ce44d50e710b277b79c8f11e9d33...
# 112738  aragorn.658427ef2395ae117298f5f418efdb650f812f...
# ...                                                   ...
# 152044  zstd.postprocessed.kiteshield-outer.b6cedac767...
# 152045  zstd.postprocessed.upx-1.bd17cf0506318084f3108...
# 152046  zstd.postprocessed.upx-1.cb0a2efb14054e20fb465...
# 152047  zstd.postprocessed.upx-best.145f04c3b68e1e3d8e...
# 152048  zstd.postprocessed.upx-best.ad219010f63c0ee973...
#
# [9396 rows x 3 columns]

# %% [markdown]
# We know that each file corresponds to a distinct binary, and that the file name encodes some versioning information (because of the way shared object versioning works on Linux) and compilation procedurals. We can thus strip these off to get a good lower bound on the number of nominally distinct binaries.

# %%
len(np.unique(subset_exp["file"].str.split(".").apply(lambda x: x[0])))
# Out:
# 265

# %% [markdown]
# ## Compiler configuration analysis

# %% [markdown]
# Since we have a running assumption that optimization and other compilation tricks alter the structure of binaries, we would presumably run experiments on binaries that share not only a certain compiler version, but also the whole build configuration. Let's index the various binaries in play by this aspect. <a name="processing-batches"></a>

# %%
compile_options = {}
for i in tqdm_notebook(subset_exp.index):
    df = pd.read_parquet(f"{PROTOCOL}://{parquets[i]}")
    compile_options_file = df["compile_options"].unique()
    assert len(compile_options_file) == 1
    compile_options[i] = compile_options_file[0]
hive["compile_options"] = pd.Series(compile_options)
hive.loc[~hive["compile_options"].isna()]
# Out:
#   0%|          | 0/9396 [00:00<?, ?it/s]
#                                      arch             compiler  \
# 112734  arch=linux-ubuntu21.04-x86_64-x86  compiler=gcc-11.1.0
# 112735  arch=linux-ubuntu21.04-x86_64-x86  compiler=gcc-11.1.0
# 112736  arch=linux-ubuntu21.04-x86_64-x86  compiler=gcc-11.1.0
# 112737  arch=linux-ubuntu21.04-x86_64-x86  compiler=gcc-11.1.0
# 112738  arch=linux-ubuntu21.04-x86_64-x86  compiler=gcc-11.1.0
# ...                                   ...                  ...
# 152044  arch=linux-ubuntu21.04-x86_64-x86  compiler=gcc-11.1.0
# 152045  arch=linux-ubuntu21.04-x86_64-x86  compiler=gcc-11.1.0
# 152046  arch=linux-ubuntu21.04-x86_64-x86  compiler=gcc-11.1.0
# 152047  arch=linux-ubuntu21.04-x86_64-x86  compiler=gcc-11.1.0
# 152048  arch=linux-ubuntu21.04-x86_64-x86  compiler=gcc-11.1.0
#
#                 package         version  \
# 112734  package=aragorn  version=1.2.36
# 112735  package=aragorn  version=1.2.36
# 112736  package=aragorn  version=1.2.36
# 112737  package=aragorn  version=1.2.36
# 112738  package=aragorn  version=1.2.36
# ...                 ...             ...
# 152044     package=zstd   version=1.4.5
# 152045     package=zstd   version=1.4.5
# 152046     package=zstd   version=1.4.5
# 152047     package=zstd   version=1.4.5
# 152048     package=zstd   version=1.4.5
#
#                                                      file compile_options
# 112734  aragorn.04e26c90c5323cc4f4677bbeed81396beba82e...             -O1
# 112735  aragorn.4ba4380fdf8f54e45ad7c138cafb9d61ede70d...             -Og
# 112736  aragorn.4fa7ba312c88261d9a2795b0d65d095c1b0548...             -O0
# 112737  aragorn.58f16bf402ce44d50e710b277b79c8f11e9d33...             -O2
# 112738  aragorn.658427ef2395ae117298f5f418efdb650f812f...
# ...                                                   ...             ...
# 152044  zstd.postprocessed.kiteshield-outer.b6cedac767...
# 152045  zstd.postprocessed.upx-1.bd17cf0506318084f3108...
# 152046  zstd.postprocessed.upx-1.cb0a2efb14054e20fb465...
# 152047  zstd.postprocessed.upx-best.145f04c3b68e1e3d8e...
# 152048  zstd.postprocessed.upx-best.ad219010f63c0ee973...
#
# [9396 rows x 6 columns]

# %% [markdown]
# The nominal non-optimized compilation configuration corresponds to option `-O0` for the GCC compiler. It also corresponds to having no compile-affecting option at all. Let's also reject all post-processings of the linked binary. How many versions do we then have for each package?

# %%
hive["postprocessing"] = (
    hive["file"]
    .str.split(".postprocessed.")
    .apply(lambda x: x[-1] if len(x) > 1 else ".asdf.parquet")
    .str.split(".")
    .apply(lambda y: ".".join(y[:-2]))
)
hive
# Out:
#                                         arch            compiler  \
# 0       arch=linux-ubuntu18.04-a64fx-AARCH64  compiler=gcc-7.5.0
# 1       arch=linux-ubuntu18.04-a64fx-AARCH64  compiler=gcc-7.5.0
# 2       arch=linux-ubuntu18.04-a64fx-AARCH64  compiler=gcc-7.5.0
# 3       arch=linux-ubuntu18.04-a64fx-AARCH64  compiler=gcc-7.5.0
# 4       arch=linux-ubuntu18.04-a64fx-AARCH64  compiler=gcc-7.5.0
# ...                                      ...                 ...
# 160926       arch=linux-ubuntu21.04-zen2-x86  compiler=gcc-9.3.0
# 160927       arch=linux-ubuntu21.04-zen2-x86  compiler=gcc-9.3.0
# 160928       arch=linux-ubuntu21.04-zen2-x86  compiler=gcc-9.3.0
# 160929       arch=linux-ubuntu21.04-zen2-x86  compiler=gcc-9.3.0
# 160930       arch=linux-ubuntu21.04-zen2-x86  compiler=gcc-9.3.0
#
#                    package         version  \
# 0       package=aeskeyfind  version=master
# 1         package=earlyoom     version=1.6
# 2           package=figlet   version=2.2.4
# 3           package=figlet   version=2.2.4
# 4            package=flash  version=1.2.11
# ...                    ...             ...
# 160926        package=zlib   version=1.2.8
# 160927        package=zlib   version=1.2.8
# 160928        package=zlib   version=1.2.8
# 160929        package=zlib   version=1.2.8
# 160930        package=zlib   version=1.2.8
#
#                                                      file compile_options  \
# 0       aeskeyfind.4c96ada082b42828d4d9ede6487f370ecbe...             NaN
# 1       earlyoom.849fe438fc62a5981db19d3e0f57338a6ecec...             NaN
# 2       chkfont.f220efe72fba81c74e7b67edeb7fb3cdbb0d7c...             NaN
# 3       figlet.5761c63e7cf0cc0086c91579005198c53bab230...             NaN
# 4       flash.f2e8ed41b3bd6732c41a81c6400003db5e3071f7...             NaN
# ...                                                   ...             ...
# 160926  libz.so.1.2.8.postprocessed.stripped.343728623...             NaN
# 160927  libz.so.1.2.8.postprocessed.stripped.387b0930f...             NaN
# 160928  libz.so.1.2.8.postprocessed.stripped.52462a04e...             NaN
# 160929  libz.so.1.2.8.postprocessed.stripped.c98d28d69...             NaN
# 160930  libz.so.1.2.8.postprocessed.stripped.d5db3d935...             NaN
#
#        postprocessing
# 0
# 1
# 2
# 3
# 4
# ...               ...
# 160926       stripped
# 160927       stripped
# 160928       stripped
# 160929       stripped
# 160930       stripped
#
# [160931 rows x 7 columns]

# %%
hive_noopt_nopost = hive.loc[hive.compile_options.isin({"", "-O0"}) & ~hive.postprocessing.apply(bool)]
hive_noopt_nopost
# Out:
#                                      arch             compiler  \
# 112736  arch=linux-ubuntu21.04-x86_64-x86  compiler=gcc-11.1.0
# 112738  arch=linux-ubuntu21.04-x86_64-x86  compiler=gcc-11.1.0
# 112747  arch=linux-ubuntu21.04-x86_64-x86  compiler=gcc-11.1.0
# 112756  arch=linux-ubuntu21.04-x86_64-x86  compiler=gcc-11.1.0
# 112758  arch=linux-ubuntu21.04-x86_64-x86  compiler=gcc-11.1.0
# ...                                   ...                  ...
# 151982  arch=linux-ubuntu21.04-x86_64-x86  compiler=gcc-11.1.0
# 152003  arch=linux-ubuntu21.04-x86_64-x86  compiler=gcc-11.1.0
# 152025  arch=linux-ubuntu21.04-x86_64-x86  compiler=gcc-11.1.0
# 152028  arch=linux-ubuntu21.04-x86_64-x86  compiler=gcc-11.1.0
# 152030  arch=linux-ubuntu21.04-x86_64-x86  compiler=gcc-11.1.0
#
#                 package           version  \
# 112736  package=aragorn    version=1.2.36
# 112738  package=aragorn    version=1.2.36
# 112747  package=aragorn    version=1.2.38
# 112756   package=argon2  version=20161029
# 112758   package=argon2  version=20161029
# ...                 ...               ...
# 151982     package=zstd     version=1.4.3
# 152003     package=zstd     version=1.4.4
# 152025     package=zstd     version=1.4.5
# 152028     package=zstd     version=1.4.5
# 152030     package=zstd     version=1.4.5
#
#                                                      file compile_options  \
# 112736  aragorn.4fa7ba312c88261d9a2795b0d65d095c1b0548...             -O0
# 112738  aragorn.658427ef2395ae117298f5f418efdb650f812f...
# 112747  aragorn.ec7b5999c8195f3225bc9c910d21c4bc4a4ae3...
# 112756  argon2.4ae4beef8818c768ef08fd62cd20ee9cb514adb...
# 112758  argon2.58ca0778d7fdf5e0281d4478170da7650b58157...             -O0
# ...                                                   ...             ...
# 151982  libzstd.so.1.4.3.5ed526a291b0b6804077a13b51dc1...
# 152003  libzstd.so.1.4.4.0dd132b969ebac53edc01d0e44f7f...
# 152025  libzstd.so.1.4.5.25ac422728b9ec12be141f63f9bf9...             -O0
# 152028  libzstd.so.1.4.5.5999c8c098d5f894042ba5b6a4ed8...
# 152030  libzstd.so.1.4.5.ad30b47d206afa2265f86dbc0e04e...
#
#        postprocessing
# 112736
# 112738
# 112747
# 112756
# 112758
# ...               ...
# 151982
# 152003
# 152025
# 152028
# 152030
#
# [1094 rows x 7 columns]

# %% [markdown]
# The dataset seems to carry distinct binaries built either with `-O0` as opposed to no option at all. How are these split?

# %%
hive_noopt_nopost.groupby("compile_options").agg({"file": "count"})
# Out:
#                  file
# compile_options
#                   455
# -O0               639

# %% [markdown]
# There are more binaries with `-O0`; furthermore, the non-optimized configuration is deliberate in this case. Likely, one would want to start experimenting with these binaries.

# %% [markdown]
# ## Known pitfall when using the dataset

# %% [markdown]
# The `pyarrow.dataset` routines are not very robust when dealing with Parquet files with a complicated schema that might be subtly non-uniform throughout. For instance, the following idiom would hang my notebook kernel:

# %% [raw]
# from pyarrow.dataset import dataset
#
# ll = []
# for batch in tqdm_notebook(dataset(ROOT, filesystem=fs).to_batches(columns=["package", "basic_blocks"])):
#     ll.append(len(batch["basic_blocks"]))

# %% [markdown]
# It seems the PyArrow code fails to handle the optimized case of loading a projection of the column space when this projection includes one of the dataset's heavily-recursive columns, such as `basic_blocks`. The workaround consists in accepting the memory and runtime hit of loading the whole of all Parquet files that contributes to one's computation. This idiom has been demonstrated [above](#processing-batches). The approach that has worked best for me has been to iterate on the Parquet leaves of my choice, loading each in sequence using Pandas:

# %% [raw]
# for i in some_leaf_subset.index:
#     data_about_binary = pd.read_parquet(f"{PROTOCOL}/{parquets[i]}")
#     # Do something with this data.

# %% [markdown]
# This simple loop is easily processed in parallel using `joblib`, or for fancier processing, using Dask. In this case, remark that `dask.dataframe.read_parquet` will run into similar problems to those raised using `pyarrow.dataset.Dataset.to_batches`. One works around using `dask.dataframe.from_delayed` and sets up a `dask.delayed` routine that invokes `pandas.read_parquet`.
